# %%
from classes import Person, Family
from table_planner import generate_table_plan
from people import people

# Generate and display table plans
table1, table2 = generate_table_plan(people, (15, 10))

print("Table 1:")
print(table1)
print("\nTable 2:")
print(table2)
# Out:
# Table 1:
# [<classes.Person object at 0x104dd6130>, <classes.Person object at 0x104dd6b80>, <classes.Person object at 0x104dd6c70>, <classes.Person object at 0x104dd61f0>, <classes.Person object at 0x104dd64f0>, <classes.Person object at 0x104dd62b0>, <classes.Person object at 0x104dd6700>, <classes.Person object at 0x104dd65b0>, <classes.Person object at 0x104dd6250>, <classes.Person object at 0x104dd6cd0>, <classes.Person object at 0x104dd6c40>, <classes.Person object at 0x104dd6820>, <classes.Person object at 0x104dd6a30>, <classes.Person object at 0x104dd6af0>, <classes.Person object at 0x104dd63d0>]
#
# Table 2:
# [<classes.Person object at 0x104dd6d90>, <classes.Person object at 0x104dd6910>, <classes.Person object at 0x104dd60d0>, <classes.Person object at 0x104dd6940>, <classes.Person object at 0x104dd6070>, <classes.Person object at 0x104dd6d30>, <classes.Person object at 0x104dd69d0>, <classes.Person object at 0x104dd6310>, <classes.Person object at 0x104dd6550>]

# %%
from utils import format_tables

print(format_tables(table1, table2))
# Out:
# Table 1: [Polo (Chaufour), Carine (ChaufourHauret), Martin (Cubertafond), Suzie (ChaufourDablanc), Martin (ChaufourHauret), Juliette (ChaufourDablanc), Melchior (Poulain), Alix (Guillot), Oscar (ChaufourDablanc), Honorine (Cubertafond), Stan (ChaufourHauret), Marie (Poulain), Maxou (Guillot), Judith (Cubertafond), JB (Guillot)]
# Table 2: [Elise (Cubertafond), Kieran (Poulain), Mamoune (Chaufour), Adrien (Guillot), Alma (Poulain), Dazz (Cubertafond), Sixtine (Guillot), Romain (ChaufourDablanc), Séverine (Guillot)]
